# %%
from eda import insufficient_but_starting_eda
import pandas as pd
import numpy as np
import seaborn as sns

# %%
comp = pd.read_csv('inputs/cust_supply_2019_2022.csv')
sp500 = pd.read_csv('inputs/sp500_2022.csv')
acct_raw = pd.read_csv("inputs/acct_data.csv")

# %% [markdown]
# # Data Sources
# - [cust_supply_2019_2022.csv](inputs/cust_supply_2019_2022.csv) provided by Dr. Bowen
# - SP500 data (obtained from scarping Wikipedia)
# - Data from the accounting dataset provided by Dr. Bowen based on variables we determined after our data cleaning on the compustat dataset
#     - Variables:
#     - fyear (fiscal year)
#     - sale (net sales)
#     - rect (receivables/total)
#     - invt (inventories)
#     - ap (accounts payable - trade)
#     - ib (income before extraordinary items)
#     - ni (net income (loss))
#     - obidp (operating income before depreciation)
#     - at (total assets)
#     - capx (capex, dollar amount)
#     - capxv (capex ratio for current fiscal year)
#     - cogs (cost of goods sold)
#     - gp (gross profit)
#     - epsfx (eps basic (takes into account the actual number of shares outstanding, and does not include any potentially dilutive securities))
#     - acominc (net income)

# %% [markdown]
# # Data
# - We acquired our data from Dr. Bowen as a .csv file
# - To load the data into python we used
#     - `pd.read_csv('inputs/cust_supply_2019_2022.csv')` for the compustat dataset
#     - `acct = pd.read_csv("inputs/acct_data.csv")` for the accounting dataset
# - We then downloaded the SP500 data by
# ```python
# os.makedirs("inputs", exist_ok=True)
# sp500_file = 'inputs/sp500_2022.csv'
#
# if not os.path.exists(sp500_file):
#     url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
#     pd.read_html(url)[0].to_csv(sp500_file,index=False)
#
# sp500 = pd.read_csv('inputs/sp500_2022.csv')
# sp500
# ```

# %% [markdown]
# # EDA - Compustat Data
# - We used `eda.py` file from the community codebook to perform EDA on the raw compustat data
# ```python
# insufficient_but_starting_eda(comp, ['cnms', 'ctype', 'gareac', 'gareat', 'stype', 'srcdate', 'conm', 'tic', 'cusip'])
# ```
# - We found that
#     - there are 77901 data entries in this csv
#     - there are 9 categorical variables
#     - there are 6 numerical variables
#     - the unit level is sales
#     - the only variables with missing data are
#         - gareac (57.8%)
#         - gareat (57.8%)
#         - stype (14.0%)
#         - salecs (12.4%)
#         - cik (0.6%)
#
# - Although more than 50% of geograpic area code (gareac) and geograpic area type (gareat) are missing, these values will not be used for our analysis and will be dropped.
# - We are also not concerned about segment type (stype) as we are going to use gics sector instead to describe the seller.
# - Often sales (salecs) are not reported when the buyer is also "not reported", therefore it is not of a concern that 12.4% of that data is blank.

# %%
insufficient_but_starting_eda(comp, ['cnms', 'ctype', 'gareac', 'gareat', 'stype', 'srcdate', 'conm', 'tic', 'cusip'])
# Out:
#    gvkey  cid             cnms   ctype  gareac gareat  salecs  sid   stype  \
# 0   1004   31        All Other  MARKET     NaN    NaN     NaN    0     NaN
# 1   1004   18  U.S. Government  GOVDOM     USA    ISO   455.9   20  BUSSEG
# 2   1004   26  U.S. Government  GOVDOM     USA    ISO    90.3   22  BUSSEG
# 3   1004   36    Europe/Africa  GEOREG  EUROPE    REG     5.8   22  BUSSEG
# 4   1004   34            Other  GEOREG   OTHER    REG   170.4   20  BUSSEG
#
#       srcdate      conm  tic      cusip     cik   sic
# 0  2019-05-31  AAR CORP  AIR  000361105  1750.0  5080
# 1  2019-05-31  AAR CORP  AIR  000361105  1750.0  5080
# 2  2019-05-31  AAR CORP  AIR  000361105  1750.0  5080
# 3  2019-05-31  AAR CORP  AIR  000361105  1750.0  5080
# 4  2019-05-31  AAR CORP  AIR  000361105  1750.0  5080
# ---
#         gvkey  cid                     cnms   ctype   gareac gareat    salecs  \
# 77896  350681    1  Large Corporate Clients  MARKET      NaN    NaN    76.814
# 77897  353444    4        Rest of the World  GEOREG  R_WORLD    REG  7148.294
# 77898  353444    3                    China  GEOREG      CHN    ISO  1084.634
# 77899  353444    2                       US  GEOREG      USA    ISO  4249.166
# 77900  353444    1                       UK  GEOREG      GBR    ISO   442.791
#
#        sid   stype     srcdate                  conm  tic      cusip  \
# 77896    1  BUSSEG  2021-12-31  GETNET ADQUIRENCIA E  GET  37428A103
# 77897    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
# 77898    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
# 77899    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
# 77900    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
#
#              cik   sic
# 77896  1867325.0  7374
# 77897        NaN  2834
# 77898        NaN  2834
# 77899        NaN  2834
# 77900        NaN  2834
# ---
# Index(['gvkey', 'cid', 'cnms', 'ctype', 'gareac', 'gareat', 'salecs', 'sid',
#        'stype', 'srcdate', 'conm', 'tic', 'cusip', 'cik', 'sic'],
#       dtype='object')
# ---
# The shape is:  (77901, 15)
# ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77901 entries, 0 to 77900
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gvkey    77901 non-null  int64
#  1   cid      77901 non-null  int64
#  2   cnms     77901 non-null  object
#  3   ctype    77901 non-null  object
#  4   gareac   32848 non-null  object
#  5   gareat   32865 non-null  object
#  6   salecs   68264 non-null  float64
#  7   sid      77901 non-null  int64
#  8   stype    67013 non-null  object
#  9   srcdate  77901 non-null  object
#  10  conm     77901 non-null  object
#  11  tic      77894 non-null  object
#  12  cusip    77901 non-null  object
#  13  cik      77419 non-null  float64
#  14  sic      77901 non-null  int64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 8.9+ MB
# Info: None
# ---
#                gvkey           cid         salecs           sid           cik  \
# count   77901.000000  77901.000000   68264.000000  77901.000000  7.741900e+04
# mean    65404.898576     27.709336     876.577773      4.974634  1.043317e+06
# std     72289.710392     28.479348    4733.002892      7.997586  5.536303e+05
# min      1004.000000      1.000000   -3464.000000      0.000000  1.750000e+03
# 25%     13189.000000      8.000000      10.400000      1.000000  8.065170e+05
# 50%     30571.000000     19.000000      75.822500      1.000000  1.076682e+06
# 75%    115044.000000     38.000000     411.142500      6.000000  1.511337e+06
# max    353444.000000    261.000000  278969.090000     99.000000  1.962738e+06
#
#                 sic
# count  77901.000000
# mean    4681.055211
# std     1997.686220
# min      100.000000
# 25%     3310.000000
# 50%     3841.000000
# 75%     6798.000000
# max     9997.000000
# ---
# cnms has 9976 values and its top 10 most common are:
# Not Reported     10597
# United States     2243
# Europe            1614
# Other             1542
# International     1382
# North America     1359
# 2 Customers        803
# Asia Pacific       743
# 3 Customers        715
# Canada             683
# Name: cnms, dtype: int64
# ---
# ctype has 7 values and its top 10 most common are:
# COMPANY     31408
# GEOREG      27754
# MARKET      16634
# GOVDOM       1707
# GOVFRN        218
# GOVSTATE      156
# GOVLOC         24
# Name: ctype, dtype: int64
# ---
# gareac has 227 values and its top 10 most common are:
# USA         5795
# OTHER       4549
# EUROPE      3024
# ASIA        2333
# N_AMER      1644
# CHN         1136
# AMERICAS     951
# CAN          781
# GBR          624
# L_AMER       541
# Name: gareac, dtype: int64
# ---
# gareat has 3 values and its top 10 most common are:
# REG      14931
# ISO      12879
# STATE     5055
# Name: gareat, dtype: int64
# ---
# stype has 3 values and its top 10 most common are:
# BUSSEG    54933
# GEOSEG     8857
# OPSEG      3223
# Name: stype, dtype: int64
# ---
# srcdate has 48 values and its top 10 most common are:
# 2019-12-31    20200
# 2020-12-31    20150
# 2021-12-31    19688
# 2020-09-30     1249
# 2019-09-30     1233
# 2021-09-30     1160
# 2019-03-31     1098
# 2020-03-31     1093
# 2021-03-31      984
# 2022-03-31      942
# Name: srcdate, dtype: int64
# ---
# conm has 4417 values and its top 10 most common are:
# GLOBAL NET LEASE INC            220
# ESSENTIAL PPT RLTY TST          217
# W P CAREY INC                   213
# EASTERLY GOVERNMENT PPTYS       208
# AGREE REALTY CORP               188
# ENEL SPA                        184
# HITACHI LTD                     183
# NECESSITY RET REIT INC (THE)    174
# BRIXMOR PROPERTY GROUP INC      164
# INDSTRL LGST PRPT TRST          164
# Name: conm, dtype: int64
# ---
# tic has 4416 values and its top 10 most common are:
# GNL      220
# EPRT     217
# WPC      213
# DEA      208
# ADC      188
# ENLAY    184
# HTHIY    183
# RTL      174
# BRX      164
# ILPT     164
# Name: tic, dtype: int64
# ---
# cusip has 4417 values and its top 10 most common are:
# 379378201    220
# 29670E107    217
# 92936U109    213
# 27616P103    208
# 008492100    188
# 29265W207    184
# 433578507    183
# 02607T109    174
# 11120U105    164
# 456237106    164
# Name: cusip, dtype: int64
# ---

# %% [markdown]
# # EDA - Accounting Data
# - We also used `eda.py` on the accounting data set also prodivided by Dr. Bowen
# ```python
# insufficient_but_starting_eda(acct)
# ```
# - We found that
#     - there are 26905 obersvations
#     - the unit level is firm year
#     - all variables are numerical as we requested them
#         - there are 16 variables
#     - the variables with missing data are
#         - capxv (16.3%)
#         - oibdp (11.4%)
#         - invt (8.9%)
#         - capx (8.7%)
#         - rect (8.5%)
#         - acominc (8.3%)
#         - ap (8.3%)
#         - epsfx (8.1%)
#         - ib (8.0%)
#         - ni (8.0%)
#         - cogs (8.0%)
#         - gp (8.0%)
#         - sale (8.0%)
#         - at (7.7%)

# %%
insufficient_but_starting_eda(acct_raw)
# Out:
#    gvkey  fyear  acominc      ap       at    capx   capxv     cogs  epsfx  \
# 0   1004   2018    -40.9   187.8   1517.2    17.4    17.4   1679.5   2.40
# 1   1004   2019    -44.6   191.6   2079.0    23.6    23.6   1728.7   0.71
# 2   1004   2020    -18.3   127.2   1539.7    11.3    11.3   1364.6   1.30
# 3   1004   2021    -19.6   156.4   1573.9    17.3    17.3   1470.3   2.16
# 4   1045   2018  -5274.0  1773.0  60580.0  3745.0  3745.0  31365.0   3.03
#
#         gp      ib    invt      ni   oibdp    rect     sale
# 0    372.3    84.1   589.0     7.5   153.5   258.1   2051.8
# 1    360.6    24.8   692.7     4.4   150.1   229.1   2089.3
# 2    286.8    46.3   591.0    35.8   101.8   238.6   1651.4
# 3    346.8    78.5   604.1    78.7   149.3   290.3   1817.1
# 4  13176.0  1412.0  1522.0  1412.0  5606.0  1706.0  44541.0
# ---
#         gvkey  fyear   acominc        ap         at     capx    capxv  \
# 26900  349972   2022     0.096     1.378     28.064    0.000    0.000
# 26901  350681   2021    -0.043  9263.248  10595.813   67.367   67.367
# 26902  351038   2021     0.000     0.923      9.357    0.000    0.000
# 26903  351038   2022     0.000     0.606     14.458    0.000    0.000
# 26904  353444   2022  1441.060  2210.991  41948.594  366.290  366.290
#
#            cogs  epsfx        gp        ib      invt        ni     oibdp  \
# 26900     0.000  -1.73     0.000   -14.323     0.000   -14.323   -14.909
# 26901   265.517   0.09   246.577    85.469     7.341    85.469   180.979
# 26902     0.000  -5.42     0.000   -21.463     0.000   -21.463    -5.959
# 26903     0.000  -3.90     0.000    -9.381     0.000    -9.381    -9.153
# 26904  4629.226   0.28  8453.578  1277.194  1624.205  1277.194  3259.254
#
#            rect       sale
# 26900     0.000      0.000
# 26901  9796.007    512.094
# 26902     0.000      0.000
# 26903     0.000      0.000
# 26904  2254.368  13082.804
# ---
# Index(['gvkey', 'fyear', 'acominc', 'ap', 'at', 'capx', 'capxv', 'cogs',
#        'epsfx', 'gp', 'ib', 'invt', 'ni', 'oibdp', 'rect', 'sale'],
#       dtype='object')
# ---
# The shape is:  (26905, 16)
# ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26905 entries, 0 to 26904
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gvkey    26905 non-null  int64
#  1   fyear    26905 non-null  int64
#  2   acominc  24669 non-null  float64
#  3   ap       24685 non-null  float64
#  4   at       24832 non-null  float64
#  5   capx     24575 non-null  float64
#  6   capxv    22514 non-null  float64
#  7   cogs     24754 non-null  float64
#  8   epsfx    24734 non-null  float64
#  9   gp       24754 non-null  float64
#  10  ib       24753 non-null  float64
#  11  invt     24499 non-null  float64
#  12  ni       24753 non-null  float64
#  13  oibdp    23838 non-null  float64
#  14  rect     24612 non-null  float64
#  15  sale     24755 non-null  float64
# dtypes: float64(14), int64(2)
# memory usage: 3.3 MB
# Info: None
# ---
#                gvkey         fyear        acominc            ap            at  \
# count   26905.000000  26905.000000   24669.000000  2.468500e+04  2.483200e+04
# mean    70110.339008   2020.003680    -193.922556  6.759971e+03  1.912273e+04
# std     72284.855281      1.395863    2356.382557  7.559164e+04  1.294296e+05
# min      1004.000000   2018.000000 -114734.000000  0.000000e+00  1.260000e-01
# 25%     19516.000000   2019.000000     -19.000000  4.484000e+00  2.125453e+02
# 50%     33695.000000   2020.000000      -0.093000  3.706200e+01  1.161340e+03
# 75%    136186.000000   2021.000000       0.000000  3.130000e+02  5.276946e+03
# max    353444.000000   2022.000000   35312.000000  2.462303e+06  3.743567e+06
#
#                capx         capxv           cogs         epsfx             gp  \
# count  24575.000000  22514.000000   24754.000000  24734.000000   24754.000000
# mean     322.056659    340.176196    3240.014061      1.082273    1779.214828
# std     1701.627139   1762.539259   16042.235726      9.804587    7586.086639
# min    -3258.000000  -3258.000000  -10210.762000   -274.650000  -17188.000000
# 25%        0.756000      0.679000      25.118500     -0.770000      15.264250
# 50%       10.503000     12.278000     194.470500      0.260000     171.645000
# 75%       86.989500     97.518750    1260.930250      2.150000     818.312750
# max    63645.000000  63645.000000  452776.000000    499.660000  250076.000000
#
#                  ib           invt            ni          oibdp          rect  \
# count  24753.000000   24499.000000  24753.000000   23838.000000  2.461200e+04
# mean     396.328359     871.847992    403.071353    1040.588721  5.614507e+03
# std     2581.707327   10892.041812   2597.676221    4599.011533  5.270339e+04
# min   -22819.000000       0.000000 -22819.000000  -17188.000000  0.000000e+00
# 25%      -28.323000       0.000000    -28.520000      -7.608000  8.683500e+00
# 50%        8.171000       4.543000      8.404000      51.933500  9.016400e+01
# 75%      147.121000     118.466500    150.611000     417.118500  6.075567e+02
# max    99803.000000  503428.000000  99803.000000  128137.000000  1.164692e+06
#
#                 sale
# count   24755.000000
# mean     5018.980743
# std     21774.263166
# min    -11591.578000
# 25%        52.153500
# 50%       422.991000
# 75%      2172.350000
# max    608481.000000
# ---

# %% [markdown]
# # Cleaning
# - Initially, on the compustat data, we filtered to just look at just company in company type (`ctype`), that query only provided us with about 150 firms. Therefore we, decided to look at all company types (`ctypes`) as it provided about twice the amount of data (about 350 firms).
# - This also provided us with a more hollistic view of the firms financials
#     - for example AAPL did not report selling to specific companies, and in the initial method would have not been included in our list of firms that we are observing
#
# The code we used to clean/filter the comp data is below:
#
# ```python
# comp2 = comp
# comp2 = comp2[comp2['cnms'] != 'Not Reported'] #dropping when the compnay name is not reported
# comp3 = comp2.dropna(subset=['salecs']) # dropping datasets with no sales data
# ```

# %% [markdown]
# # Merging
# - Before merging, we made sure our columns in compustat matched the names in the SP500 dataset
#     - We renamed `cik` to `CIK` to match
# ```python
# comp3 = comp3.rename(columns = {'cik': 'CIK'})
# merged = comp3.merge(sp500, on='CIK', how = 'inner')
# ```

# %% [markdown]
# # Finalizing the Dataset
# - Since we are only looking at firms that filed in 2019 and 2022 we needed to make sure our dataset represented the accurate years
# ```python
# start_date = '2020-01-01'
# end_date = '2021-12-31'
# filtered_df = merged.query('@start_date <= date <= @end_date')
# # get the indices of the filtered dates
# filtered_indices = filtered_df.index
# # drop the filtered dates from the original dataframe
# filtered_out_df = merged.drop(filtered_indices)
# ```

# %% [markdown]
# # Caveats/Going Forward
# - For this dataset we are going to say that any firm filing in 2019 corresponds to information in 2019 fiscal year
#     - We know that this can lead to some inaccuracies when firms don't file in 2019 for 2019 fiscal year.
#     - For instance if a firm files in January of 2020 our analysis is that this data will correspond with the fiscal year of 2020, wehn in reality the data actually corresponds with 2019 fiscal year
#     - TLDR: the fiscal year = the filing year
#
# Going Forward
# - Correcting above
# - Adding years 2020 and 2021 to the analysis

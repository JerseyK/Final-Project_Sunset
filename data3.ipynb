# %% [markdown]
#  ## Data Analysis

# %% [markdown]
# ### Here is a breakdown of what each column represents:
#
# - gvkey: a unique identifier for the company (Global Company Key)
# - cid: a unique identifier for the customer
# - cnms: customer name
# - ctype: customer type
# - gareac: geographic area code
# - gareat: geographic area type
# - salecs: sales in current period (in millions)
# - sid: segment identifier
# - stype: segment type
# - srcdate: source date
# - conm: company name
# - tic: stock ticker symbol
# - cusip: CUSIP number, a unique identifier for a security
# - cik: SEC Central Index Key, a unique identifier for a company
# - sic: Standard Industrial Classification code, a numerical code used to classify industries

# %%
## imports
import pandas as pd
import numpy as np
import os
from eda import insufficient_but_starting_eda
import seaborn as sns

# %% [markdown]
# ## Getting the SP500 data

# %%
## downloading the SP500 info from the web
os.makedirs("inputs", exist_ok=True)
sp500_file = 'inputs/sp500_2022.csv'

if not os.path.exists(sp500_file):
    url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    pd.read_html(url)[0].to_csv(sp500_file,index=False)

# %%
comp = pd.read_csv('inputs/cust_supply_2019_2022.csv')
comp
# Out:
#         gvkey  cid                     cnms   ctype   gareac gareat    salecs  \
# 0        1004   31                All Other  MARKET      NaN    NaN       NaN
# 1        1004   18          U.S. Government  GOVDOM      USA    ISO   455.900
# 2        1004   26          U.S. Government  GOVDOM      USA    ISO    90.300
# 3        1004   36            Europe/Africa  GEOREG   EUROPE    REG     5.800
# 4        1004   34                    Other  GEOREG    OTHER    REG   170.400
# ...       ...  ...                      ...     ...      ...    ...       ...
# 77896  350681    1  Large Corporate Clients  MARKET      NaN    NaN    76.814
# 77897  353444    4        Rest of the World  GEOREG  R_WORLD    REG  7148.294
# 77898  353444    3                    China  GEOREG      CHN    ISO  1084.634
# 77899  353444    2                       US  GEOREG      USA    ISO  4249.166
# 77900  353444    1                       UK  GEOREG      GBR    ISO   442.791
#
#        sid   stype     srcdate                  conm  tic      cusip  \
# 0        0     NaN  2019-05-31              AAR CORP  AIR  000361105
# 1       20  BUSSEG  2019-05-31              AAR CORP  AIR  000361105
# 2       22  BUSSEG  2019-05-31              AAR CORP  AIR  000361105
# 3       22  BUSSEG  2019-05-31              AAR CORP  AIR  000361105
# 4       20  BUSSEG  2019-05-31              AAR CORP  AIR  000361105
# ...    ...     ...         ...                   ...  ...        ...
# 77896    1  BUSSEG  2021-12-31  GETNET ADQUIRENCIA E  GET  37428A103
# 77897    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
# 77898    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
# 77899    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
# 77900    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
#
#              cik   sic
# 0         1750.0  5080
# 1         1750.0  5080
# 2         1750.0  5080
# 3         1750.0  5080
# 4         1750.0  5080
# ...          ...   ...
# 77896  1867325.0  7374
# 77897        NaN  2834
# 77898        NaN  2834
# 77899        NaN  2834
# 77900        NaN  2834
#
# [77901 rows x 15 columns]

# %%
sp500 = pd.read_csv('inputs/sp500_2022.csv')
sp500
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# 2                 Health Care Equipment  North Chicago, Illinois  1957-03-04
# 3                       Pharmaceuticals  North Chicago, Illinois  2012-12-31
# 4        IT Consulting & Other Services          Dublin, Ireland  2011-07-06
# ..                                  ...                      ...         ...
# 498                         Restaurants     Louisville, Kentucky  1997-10-06
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois  2019-12-23
# 500               Health Care Equipment          Warsaw, Indiana  2001-08-07
# 501                      Regional Banks     Salt Lake City, Utah  2001-06-22
# 502                     Pharmaceuticals   Parsippany, New Jersey  2013-06-21
#
#          CIK      Founded
# 0      66740         1902
# 1      91142         1916
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4    1467373         1989
# ..       ...          ...
# 498  1041061         1997
# 499   877212         1969
# 500  1136869         1927
# 501   109380         1873
# 502  1555280         1952
#
# [503 rows x 8 columns]

# %% [markdown]
# # Merging the data

# %%
# Select rows where 'cnms' is not equal to 'U.S. Government'

comp2 = comp
#comp2 = comp[comp['ctype'] == 'COMPANY']
comp2 = comp2[comp2['cnms'] != 'Not Reported']
# comp4 = comp2[comp2['cnms'] == 'Not Reported']
# comp4

comp3 = comp2.dropna(subset=['salecs'])
comp3

compzzz = comp2[comp2['cnms'] == 'Not Reported']  # we checked to see if these companies were in sp500, they were not, so deleting them was ok
#checking here!
compzzz = compzzz.rename(columns = {'cik': 'CIK'})
testng_merge = compzzz.merge(sp500, on='CIK', how = 'inner', indicator=True)

# %%
comp3 = comp3.rename(columns = {'cik': 'CIK'})
merged = comp3.merge(sp500, on='CIK', how = 'inner')
merged

#merged['CIK'].nunique() #385 values
# Out:
#        gvkey  cid                                     cnms    ctype gareac  \
# 0       1075   22  Retail non-residential electric service   MARKET    NaN
# 1       1075   21      Retail residential electric service   MARKET    NaN
# 2       1075   23                   Wholesale energy sales   MARKET    NaN
# 3       1075   25                            Other sources   MARKET    NaN
# 4       1075   24         Transmission services for others   MARKET    NaN
# ...      ...  ...                                      ...      ...    ...
# 9104  316056    3                             10 Customers  COMPANY    NaN
# 9105  316056    8                                 Non-U.S.   GEOREG  OTHER
# 9106  316056    4                            United States   GEOREG    USA
# 9107  316056    3                             10 Customers  COMPANY    NaN
# 9108  316056    3                             10 Customers  COMPANY    NaN
#
#      gareat    salecs  sid   stype     srcdate  ...      cusip        CIK  \
# 0       NaN  1509.514    9  BUSSEG  2019-12-31  ...  723484101   764622.0
# 1       NaN  1761.122    9  BUSSEG  2019-12-31  ...  723484101   764622.0
# 2       NaN   121.805    9  BUSSEG  2019-12-31  ...  723484101   764622.0
# 3       NaN    16.308    9  BUSSEG  2019-12-31  ...  723484101   764622.0
# 4       NaN    62.460    9  BUSSEG  2019-12-31  ...  723484101   764622.0
# ...     ...       ...  ...     ...         ...  ...        ...        ...
# 9104    NaN   656.420    1  BUSSEG  2019-12-31  ...  G0176J109  1579241.0
# 9105    REG   814.400    1  BUSSEG  2020-12-31  ...  G0176J109  1579241.0
# 9106    ISO  1905.500    1  BUSSEG  2020-12-31  ...  G0176J109  1579241.0
# 9107    NaN   652.776    1  BUSSEG  2020-12-31  ...  G0176J109  1579241.0
# 9108    NaN   716.850    0     NaN  2021-12-31  ...  G0176J109  1579241.0
#
#        sic  Symbol       Security  GICS Sector  GICS Sub-Industry  \
# 0     4911     PNW  Pinnacle West    Utilities    Multi-Utilities
# 1     4911     PNW  Pinnacle West    Utilities    Multi-Utilities
# 2     4911     PNW  Pinnacle West    Utilities    Multi-Utilities
# 3     4911     PNW  Pinnacle West    Utilities    Multi-Utilities
# 4     4911     PNW  Pinnacle West    Utilities    Multi-Utilities
# ...    ...     ...            ...          ...                ...
# 9104  3420    ALLE       Allegion  Industrials  Building Products
# 9105  3420    ALLE       Allegion  Industrials  Building Products
# 9106  3420    ALLE       Allegion  Industrials  Building Products
# 9107  3420    ALLE       Allegion  Industrials  Building Products
# 9108  3420    ALLE       Allegion  Industrials  Building Products
#
#         Headquarters Location  Date added Founded
# 0            Phoenix, Arizona  1999-10-04    1985
# 1            Phoenix, Arizona  1999-10-04    1985
# 2            Phoenix, Arizona  1999-10-04    1985
# 3            Phoenix, Arizona  1999-10-04    1985
# 4            Phoenix, Arizona  1999-10-04    1985
# ...                       ...         ...     ...
# 9104  New York City, New York  2013-12-02    1908
# 9105  New York City, New York  2013-12-02    1908
# 9106  New York City, New York  2013-12-02    1908
# 9107  New York City, New York  2013-12-02    1908
# 9108  New York City, New York  2013-12-02    1908
#
# [9109 rows x 22 columns]

# %%
#looking at the dates - see there is a filing in every month...
merged['date'] = pd.to_datetime(merged['srcdate'])
dates = merged.sort_values(by='srcdate')
print(dates['srcdate'])
# Out:
# 1027    2019-01-31
# 7409    2019-01-31
# 8211    2019-01-31
# 7407    2019-01-31
# 7406    2019-01-31
#            ...
# 518     2022-12-31
# 519     2022-12-31
# 520     2022-12-31
# 3172    2022-12-31
# 8108    2022-12-31
# Name: srcdate, Length: 9109, dtype: object

# %%
start_date = '2020-01-01'
end_date = '2021-12-31'
filtered_df = merged.query('@start_date <= date <= @end_date')

# get the indices of the filtered dates
filtered_indices = filtered_df.index

# drop the filtered dates from the original dataframe
filtered_out_df = merged.drop(filtered_indices)

filtered_out_df
#filtered_out_df['CIK'].nunique() #355 values
# Out:
#        gvkey  cid                                     cnms    ctype gareac  \
# 0       1075   22  Retail non-residential electric service   MARKET    NaN
# 1       1075   21      Retail residential electric service   MARKET    NaN
# 2       1075   23                   Wholesale energy sales   MARKET    NaN
# 3       1075   25                            Other sources   MARKET    NaN
# 4       1075   24         Transmission services for others   MARKET    NaN
# ...      ...  ...                                      ...      ...    ...
# 9062  189491    4                                Treatment   MARKET    NaN
# 9063  189491    3                                Transport   MARKET    NaN
# 9102  316056    8                                 Non-U.S.   GEOREG  OTHER
# 9103  316056    4                            United States   GEOREG    USA
# 9104  316056    3                             10 Customers  COMPANY    NaN
#
#      gareat    salecs  sid   stype     srcdate  ...        CIK   sic Symbol  \
# 0       NaN  1509.514    9  BUSSEG  2019-12-31  ...   764622.0  4911    PNW
# 1       NaN  1761.122    9  BUSSEG  2019-12-31  ...   764622.0  4911    PNW
# 2       NaN   121.805    9  BUSSEG  2019-12-31  ...   764622.0  4911    PNW
# 3       NaN    16.308    9  BUSSEG  2019-12-31  ...   764622.0  4911    PNW
# 4       NaN    62.460    9  BUSSEG  2019-12-31  ...   764622.0  4911    PNW
# ...     ...       ...  ...     ...         ...  ...        ...   ...    ...
# 9062    NaN   397.000    1  BUSSEG  2019-12-31  ...  1524472.0  3561    XYL
# 9063    NaN  1780.000    1  BUSSEG  2019-12-31  ...  1524472.0  3561    XYL
# 9102    REG   865.100    1  BUSSEG  2019-12-31  ...  1579241.0  3420   ALLE
# 9103    ISO  1988.900    1  BUSSEG  2019-12-31  ...  1579241.0  3420   ALLE
# 9104    NaN   656.420    1  BUSSEG  2019-12-31  ...  1579241.0  3420   ALLE
#
#            Security  GICS Sector  \
# 0     Pinnacle West    Utilities
# 1     Pinnacle West    Utilities
# 2     Pinnacle West    Utilities
# 3     Pinnacle West    Utilities
# 4     Pinnacle West    Utilities
# ...             ...          ...
# 9062     Xylem Inc.  Industrials
# 9063     Xylem Inc.  Industrials
# 9102       Allegion  Industrials
# 9103       Allegion  Industrials
# 9104       Allegion  Industrials
#
#                                  GICS Sub-Industry    Headquarters Location  \
# 0                                  Multi-Utilities         Phoenix, Arizona
# 1                                  Multi-Utilities         Phoenix, Arizona
# 2                                  Multi-Utilities         Phoenix, Arizona
# 3                                  Multi-Utilities         Phoenix, Arizona
# 4                                  Multi-Utilities         Phoenix, Arizona
# ...                                            ...                      ...
# 9062  Industrial Machinery & Supplies & Components   White Plains, New York
# 9063  Industrial Machinery & Supplies & Components   White Plains, New York
# 9102                             Building Products  New York City, New York
# 9103                             Building Products  New York City, New York
# 9104                             Building Products  New York City, New York
#
#       Date added Founded       date
# 0     1999-10-04    1985 2019-12-31
# 1     1999-10-04    1985 2019-12-31
# 2     1999-10-04    1985 2019-12-31
# 3     1999-10-04    1985 2019-12-31
# 4     1999-10-04    1985 2019-12-31
# ...          ...     ...        ...
# 9062  2011-11-01    2011 2019-12-31
# 9063  2011-11-01    2011 2019-12-31
# 9102  2013-12-02    1908 2019-12-31
# 9103  2013-12-02    1908 2019-12-31
# 9104  2013-12-02    1908 2019-12-31
#
# [3476 rows x 23 columns]

# %%
listkeys = pd.DataFrame(filtered_out_df['gvkey'].unique())
listkeys.to_csv('inputs/listkeys.csv', index=False)

# %%
g = merged.groupby("CIK")['cnms'].apply(lambda x: list(np.unique(x)))
len(g)
# Out:
# 358

# %% [markdown]
# ### EDA

# %%
insufficient_but_starting_eda(comp, ['cnms', 'ctype', 'gareac', 'gareat', 
                            'stype', 'srcdate', 'conm', 'tic', 'cusip'])
# Out:
#    gvkey  cid             cnms   ctype  gareac gareat  salecs  sid   stype  \
# 0   1004   31        All Other  MARKET     NaN    NaN     NaN    0     NaN
# 1   1004   18  U.S. Government  GOVDOM     USA    ISO   455.9   20  BUSSEG
# 2   1004   26  U.S. Government  GOVDOM     USA    ISO    90.3   22  BUSSEG
# 3   1004   36    Europe/Africa  GEOREG  EUROPE    REG     5.8   22  BUSSEG
# 4   1004   34            Other  GEOREG   OTHER    REG   170.4   20  BUSSEG
#
#       srcdate      conm  tic      cusip     cik   sic
# 0  2019-05-31  AAR CORP  AIR  000361105  1750.0  5080
# 1  2019-05-31  AAR CORP  AIR  000361105  1750.0  5080
# 2  2019-05-31  AAR CORP  AIR  000361105  1750.0  5080
# 3  2019-05-31  AAR CORP  AIR  000361105  1750.0  5080
# 4  2019-05-31  AAR CORP  AIR  000361105  1750.0  5080
# ---
#         gvkey  cid                     cnms   ctype   gareac gareat    salecs  \
# 77896  350681    1  Large Corporate Clients  MARKET      NaN    NaN    76.814
# 77897  353444    4        Rest of the World  GEOREG  R_WORLD    REG  7148.294
# 77898  353444    3                    China  GEOREG      CHN    ISO  1084.634
# 77899  353444    2                       US  GEOREG      USA    ISO  4249.166
# 77900  353444    1                       UK  GEOREG      GBR    ISO   442.791
#
#        sid   stype     srcdate                  conm  tic      cusip  \
# 77896    1  BUSSEG  2021-12-31  GETNET ADQUIRENCIA E  GET  37428A103
# 77897    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
# 77898    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
# 77899    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
# 77900    1  BUSSEG  2021-12-31            HALEON PLC  HLN  405552100
#
#              cik   sic
# 77896  1867325.0  7374
# 77897        NaN  2834
# 77898        NaN  2834
# 77899        NaN  2834
# 77900        NaN  2834
# ---
# Index(['gvkey', 'cid', 'cnms', 'ctype', 'gareac', 'gareat', 'salecs', 'sid',
#        'stype', 'srcdate', 'conm', 'tic', 'cusip', 'cik', 'sic'],
#       dtype='object')
# ---
# The shape is:  (77901, 15)
# ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77901 entries, 0 to 77900
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gvkey    77901 non-null  int64
#  1   cid      77901 non-null  int64
#  2   cnms     77901 non-null  object
#  3   ctype    77901 non-null  object
#  4   gareac   32848 non-null  object
#  5   gareat   32865 non-null  object
#  6   salecs   68264 non-null  float64
#  7   sid      77901 non-null  int64
#  8   stype    67013 non-null  object
#  9   srcdate  77901 non-null  object
#  10  conm     77901 non-null  object
#  11  tic      77894 non-null  object
#  12  cusip    77901 non-null  object
#  13  cik      77419 non-null  float64
#  14  sic      77901 non-null  int64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 8.9+ MB
# Info: None
# ---
#                gvkey           cid         salecs           sid           cik  \
# count   77901.000000  77901.000000   68264.000000  77901.000000  7.741900e+04
# mean    65404.898576     27.709336     876.577773      4.974634  1.043317e+06
# std     72289.710392     28.479348    4733.002892      7.997586  5.536303e+05
# min      1004.000000      1.000000   -3464.000000      0.000000  1.750000e+03
# 25%     13189.000000      8.000000      10.400000      1.000000  8.065170e+05
# 50%     30571.000000     19.000000      75.822500      1.000000  1.076682e+06
# 75%    115044.000000     38.000000     411.142500      6.000000  1.511337e+06
# max    353444.000000    261.000000  278969.090000     99.000000  1.962738e+06
#
#                 sic
# count  77901.000000
# mean    4681.055211
# std     1997.686220
# min      100.000000
# 25%     3310.000000
# 50%     3841.000000
# 75%     6798.000000
# max     9997.000000
# ---
# cnms has 9976 values and its top 10 most common are:
# Not Reported     10597
# United States     2243
# Europe            1614
# Other             1542
# International     1382
# North America     1359
# 2 Customers        803
# Asia Pacific       743
# 3 Customers        715
# Canada             683
# Name: cnms, dtype: int64
# ---
# ctype has 7 values and its top 10 most common are:
# COMPANY     31408
# GEOREG      27754
# MARKET      16634
# GOVDOM       1707
# GOVFRN        218
# GOVSTATE      156
# GOVLOC         24
# Name: ctype, dtype: int64
# ---
# gareac has 227 values and its top 10 most common are:
# USA         5795
# OTHER       4549
# EUROPE      3024
# ASIA        2333
# N_AMER      1644
# CHN         1136
# AMERICAS     951
# CAN          781
# GBR          624
# L_AMER       541
# Name: gareac, dtype: int64
# ---
# gareat has 3 values and its top 10 most common are:
# REG      14931
# ISO      12879
# STATE     5055
# Name: gareat, dtype: int64
# ---
# stype has 3 values and its top 10 most common are:
# BUSSEG    54933
# GEOSEG     8857
# OPSEG      3223
# Name: stype, dtype: int64
# ---
# srcdate has 48 values and its top 10 most common are:
# 2019-12-31    20200
# 2020-12-31    20150
# 2021-12-31    19688
# 2020-09-30     1249
# 2019-09-30     1233
# 2021-09-30     1160
# 2019-03-31     1098
# 2020-03-31     1093
# 2021-03-31      984
# 2022-03-31      942
# Name: srcdate, dtype: int64
# ---
# conm has 4417 values and its top 10 most common are:
# GLOBAL NET LEASE INC            220
# ESSENTIAL PPT RLTY TST          217
# W P CAREY INC                   213
# EASTERLY GOVERNMENT PPTYS       208
# AGREE REALTY CORP               188
# ENEL SPA                        184
# HITACHI LTD                     183
# NECESSITY RET REIT INC (THE)    174
# BRIXMOR PROPERTY GROUP INC      164
# INDSTRL LGST PRPT TRST          164
# Name: conm, dtype: int64
# ---
# tic has 4416 values and its top 10 most common are:
# GNL      220
# EPRT     217
# WPC      213
# DEA      208
# ADC      188
# ENLAY    184
# HTHIY    183
# RTL      174
# BRX      164
# ILPT     164
# Name: tic, dtype: int64
# ---
# cusip has 4417 values and its top 10 most common are:
# 379378201    220
# 29670E107    217
# 92936U109    213
# 27616P103    208
# 008492100    188
# 29265W207    184
# 433578507    183
# 02607T109    174
# 11120U105    164
# 456237106    164
# Name: cusip, dtype: int64
# ---

# %%
comp.describe() # describes integers
# Out:
#                gvkey           cid         salecs           sid           cik  \
# count   77901.000000  77901.000000   68264.000000  77901.000000  7.741900e+04
# mean    65404.898576     27.709336     876.577773      4.974634  1.043317e+06
# std     72289.710392     28.479348    4733.002892      7.997586  5.536303e+05
# min      1004.000000      1.000000   -3464.000000      0.000000  1.750000e+03
# 25%     13189.000000      8.000000      10.400000      1.000000  8.065170e+05
# 50%     30571.000000     19.000000      75.822500      1.000000  1.076682e+06
# 75%    115044.000000     38.000000     411.142500      6.000000  1.511337e+06
# max    353444.000000    261.000000  278969.090000     99.000000  1.962738e+06
#
#                 sic
# count  77901.000000
# mean    4681.055211
# std     1997.686220
# min      100.000000
# 25%     3310.000000
# 50%     3841.000000
# 75%     6798.000000
# max     9997.000000

# %%
##missing values
ccm = comp
(
    ( # these lines do the calculation - what % of missing values are there for each var
        ccm.isna()      # ccm.isna() TURNS every obs/variable = 1 when its missing and 0 else
       .sum(axis=0)     # count the number of na for each variable (now data is 1 obs per column = # missing)
        /len(ccm)       # convert # missing to % missing 
        *100            # report as percentage
    ) 
    # you can stop here and report this...
    # but I wanted to format it a bit...
    .sort_values(ascending=False)[:13]
    .to_frame(name='% missing') # the next line only works on a frame, and because pandas sees only 1 variable at this pt
    .style.format("{:.1f}")     # in the code, it calls this a "series" type object, so convert it to dataframe type object
)
#
# Out:
# <style type="text/css">
# </style>
# <table id="T_31098">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31098_level0_col0" class="col_heading level0 col0" >% missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31098_level0_row0" class="row_heading level0 row0" >gareac</th>
#       <td id="T_31098_row0_col0" class="data row0 col0" >57.8</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row1" class="row_heading level0 row1" >gareat</th>
#       <td id="T_31098_row1_col0" class="data row1 col0" >57.8</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row2" class="row_heading level0 row2" >stype</th>
#       <td id="T_31098_row2_col0" class="data row2 col0" >14.0</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row3" class="row_heading level0 row3" >salecs</th>
#       <td id="T_31098_row3_col0" class="data row3 col0" >12.4</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row4" class="row_heading level0 row4" >cik</th>
#       <td id="T_31098_row4_col0" class="data row4 col0" >0.6</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row5" class="row_heading level0 row5" >tic</th>
#       <td id="T_31098_row5_col0" class="data row5 col0" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row6" class="row_heading level0 row6" >gvkey</th>
#       <td id="T_31098_row6_col0" class="data row6 col0" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row7" class="row_heading level0 row7" >cid</th>
#       <td id="T_31098_row7_col0" class="data row7 col0" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row8" class="row_heading level0 row8" >cnms</th>
#       <td id="T_31098_row8_col0" class="data row8 col0" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row9" class="row_heading level0 row9" >ctype</th>
#       <td id="T_31098_row9_col0" class="data row9 col0" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row10" class="row_heading level0 row10" >sid</th>
#       <td id="T_31098_row10_col0" class="data row10 col0" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row11" class="row_heading level0 row11" >srcdate</th>
#       <td id="T_31098_row11_col0" class="data row11 col0" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_31098_level0_row12" class="row_heading level0 row12" >conm</th>
#       <td id="T_31098_row12_col0" class="data row12 col0" >0.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## several calculations

# %%
#merged

# %% [markdown]
# ### Percentage1: 'ctype', 'GICS Sector', 'srcdate' and 'salecs'

# %%
# Group the data by ctype, GICS Sector, and srcdate
grouped1 = merged.groupby(['ctype', 'GICS Sector', 'srcdate'])

# Calculate the sum of salecs for each group
totals1 = grouped1['salecs'].sum()

# Calculate the percentage of salecs in each group
percentages1 = totals1.groupby(['ctype', 'GICS Sector']).apply(lambda x: 100 * x / float(x.sum()))

# Print the result
print(percentages1)

# percentages.reset_index().to_csv('inputs/percentages1.csv', index=False)
# Out:
# ctype    GICS Sector             srcdate
# COMPANY  Communication Services  2019-03-31     6.115293
#                                  2019-12-31    21.917325
#                                  2020-03-31     7.659017
#                                  2020-12-31    22.158273
#                                  2021-03-31     8.716608
#                                                  ...
# MARKET   Real Estate             2020-12-31    23.131981
#                                  2021-12-31    33.835824
#          Utilities               2019-12-31    32.657454
#                                  2020-12-31    32.006205
#                                  2021-12-31    35.336341
# Name: salecs, Length: 465, dtype: float64

# %% [markdown]
# ### Percentage2: based on Ctype

# %%
# Extract the year from srcdate
merged2 = merged
merged2['year'] = pd.to_datetime(merged2['srcdate']).dt.year

# Group the data by ctype, year, and GICS Sector
grouped2 = merged2.groupby(['ctype', 'year', 'GICS Sector'])

# Calculate the sum of salecs for each group
totals2 = grouped2['salecs'].sum()

# Calculate the percentage of salecs in each group
percentages2 = totals2.groupby(['ctype', 'year']).apply(lambda x: 100 * x / float(x.sum()))

# Print the result
print(percentages2)
# Out:
# ctype    year  GICS Sector
# COMPANY  2019  Communication Services     1.756172
#                Consumer Discretionary     3.525216
#                Consumer Staples          17.555044
#                Energy                     1.492252
#                Financials                 2.879877
#                                            ...
# MARKET   2022  Consumer Staples          22.805041
#                Health Care                0.623047
#                Industrials                2.135718
#                Information Technology    60.742359
#                Materials                  1.155348
# Name: salecs, Length: 149, dtype: float64

# %% [markdown]
# ### Percentage3: based on GICS Sector

# %%
# Extract the year from srcdate
merged2 = merged
merged2['year'] = pd.to_datetime(merged2['srcdate']).dt.year

# Group the data by ctype, year, and GICS Sector
grouped2 = merged2.groupby(['GICS Sector', 'year', 'ctype'])

# Calculate the sum of salecs for each group
totals2 = grouped2['salecs'].sum()

# Calculate the percentage of salecs in each group
sum3 = totals2.groupby(['GICS Sector', 'year', 'ctype']).apply(lambda x: x.sum())
sum3.reset_index().to_csv('inputs/sum3.csv', index=False)

# Print the result
print(sum3)
# Out:
# GICS Sector             year  ctype
# Communication Services  2019  COMPANY     15996.741
#                               GEOREG     349817.698
#                               MARKET     126288.804
#                         2020  COMPANY     17015.159
#                               GEOREG     379065.473
#                                             ...
# Utilities               2020  MARKET     256173.752
#                         2021  COMPANY      2939.200
#                               GEOREG      26414.000
#                               GOVDOM        783.000
#                               MARKET     282827.750
# Name: salecs, Length: 149, dtype: float64

# %% [markdown]
# # Accounting Data

# %%
acct_raw = pd.read_csv("inputs/acct_data.csv")
acct_raw



# df = df.rename(columns={'A': 'new_title'})
listkeys2 = listkeys.rename(columns={0: 'gvkey'})
listkeys2

merged_acct_raw_keys = pd.merge(listkeys2,acct_raw,how = 'inner', on='gvkey')
merged_acct_raw_keys['gvkey'].nunique()
# Out:
# 354

# %%
insufficient_but_starting_eda(acct_raw)
# Out:
#    gvkey  fyear  acominc      ap       at    capx   capxv     cogs  epsfx  \
# 0   1004   2018    -40.9   187.8   1517.2    17.4    17.4   1679.5   2.40
# 1   1004   2019    -44.6   191.6   2079.0    23.6    23.6   1728.7   0.71
# 2   1004   2020    -18.3   127.2   1539.7    11.3    11.3   1364.6   1.30
# 3   1004   2021    -19.6   156.4   1573.9    17.3    17.3   1470.3   2.16
# 4   1045   2018  -5274.0  1773.0  60580.0  3745.0  3745.0  31365.0   3.03
#
#         gp      ib    invt      ni   oibdp    rect     sale
# 0    372.3    84.1   589.0     7.5   153.5   258.1   2051.8
# 1    360.6    24.8   692.7     4.4   150.1   229.1   2089.3
# 2    286.8    46.3   591.0    35.8   101.8   238.6   1651.4
# 3    346.8    78.5   604.1    78.7   149.3   290.3   1817.1
# 4  13176.0  1412.0  1522.0  1412.0  5606.0  1706.0  44541.0
# ---
#         gvkey  fyear   acominc        ap         at     capx    capxv  \
# 26900  349972   2022     0.096     1.378     28.064    0.000    0.000
# 26901  350681   2021    -0.043  9263.248  10595.813   67.367   67.367
# 26902  351038   2021     0.000     0.923      9.357    0.000    0.000
# 26903  351038   2022     0.000     0.606     14.458    0.000    0.000
# 26904  353444   2022  1441.060  2210.991  41948.594  366.290  366.290
#
#            cogs  epsfx        gp        ib      invt        ni     oibdp  \
# 26900     0.000  -1.73     0.000   -14.323     0.000   -14.323   -14.909
# 26901   265.517   0.09   246.577    85.469     7.341    85.469   180.979
# 26902     0.000  -5.42     0.000   -21.463     0.000   -21.463    -5.959
# 26903     0.000  -3.90     0.000    -9.381     0.000    -9.381    -9.153
# 26904  4629.226   0.28  8453.578  1277.194  1624.205  1277.194  3259.254
#
#            rect       sale
# 26900     0.000      0.000
# 26901  9796.007    512.094
# 26902     0.000      0.000
# 26903     0.000      0.000
# 26904  2254.368  13082.804
# ---
# Index(['gvkey', 'fyear', 'acominc', 'ap', 'at', 'capx', 'capxv', 'cogs',
#        'epsfx', 'gp', 'ib', 'invt', 'ni', 'oibdp', 'rect', 'sale'],
#       dtype='object')
# ---
# The shape is:  (26905, 16)
# ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26905 entries, 0 to 26904
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gvkey    26905 non-null  int64
#  1   fyear    26905 non-null  int64
#  2   acominc  24669 non-null  float64
#  3   ap       24685 non-null  float64
#  4   at       24832 non-null  float64
#  5   capx     24575 non-null  float64
#  6   capxv    22514 non-null  float64
#  7   cogs     24754 non-null  float64
#  8   epsfx    24734 non-null  float64
#  9   gp       24754 non-null  float64
#  10  ib       24753 non-null  float64
#  11  invt     24499 non-null  float64
#  12  ni       24753 non-null  float64
#  13  oibdp    23838 non-null  float64
#  14  rect     24612 non-null  float64
#  15  sale     24755 non-null  float64
# dtypes: float64(14), int64(2)
# memory usage: 3.3 MB
# Info: None
# ---
#                gvkey         fyear        acominc            ap            at  \
# count   26905.000000  26905.000000   24669.000000  2.468500e+04  2.483200e+04
# mean    70110.339008   2020.003680    -193.922556  6.759971e+03  1.912273e+04
# std     72284.855281      1.395863    2356.382557  7.559164e+04  1.294296e+05
# min      1004.000000   2018.000000 -114734.000000  0.000000e+00  1.260000e-01
# 25%     19516.000000   2019.000000     -19.000000  4.484000e+00  2.125453e+02
# 50%     33695.000000   2020.000000      -0.093000  3.706200e+01  1.161340e+03
# 75%    136186.000000   2021.000000       0.000000  3.130000e+02  5.276946e+03
# max    353444.000000   2022.000000   35312.000000  2.462303e+06  3.743567e+06
#
#                capx         capxv           cogs         epsfx             gp  \
# count  24575.000000  22514.000000   24754.000000  24734.000000   24754.000000
# mean     322.056659    340.176196    3240.014061      1.082273    1779.214828
# std     1701.627139   1762.539259   16042.235726      9.804587    7586.086639
# min    -3258.000000  -3258.000000  -10210.762000   -274.650000  -17188.000000
# 25%        0.756000      0.679000      25.118500     -0.770000      15.264250
# 50%       10.503000     12.278000     194.470500      0.260000     171.645000
# 75%       86.989500     97.518750    1260.930250      2.150000     818.312750
# max    63645.000000  63645.000000  452776.000000    499.660000  250076.000000
#
#                  ib           invt            ni          oibdp          rect  \
# count  24753.000000   24499.000000  24753.000000   23838.000000  2.461200e+04
# mean     396.328359     871.847992    403.071353    1040.588721  5.614507e+03
# std     2581.707327   10892.041812   2597.676221    4599.011533  5.270339e+04
# min   -22819.000000       0.000000 -22819.000000  -17188.000000  0.000000e+00
# 25%      -28.323000       0.000000    -28.520000      -7.608000  8.683500e+00
# 50%        8.171000       4.543000      8.404000      51.933500  9.016400e+01
# 75%      147.121000     118.466500    150.611000     417.118500  6.075567e+02
# max    99803.000000  503428.000000  99803.000000  128137.000000  1.164692e+06
#
#                 sale
# count   24755.000000
# mean     5018.980743
# std     21774.263166
# min    -11591.578000
# 25%        52.153500
# 50%       422.991000
# 75%      2172.350000
# max    608481.000000
# ---

# %%
acct_raw.describe()
acct_raw['gvkey']
# Out:
# 0          1004
# 1          1004
# 2          1004
# 3          1004
# 4          1045
#           ...
# 26900    349972
# 26901    350681
# 26902    351038
# 26903    351038
# 26904    353444
# Name: gvkey, Length: 26905, dtype: int64

# %%
##missing values
ccm = acct_raw
(
    ( # these lines do the calculation - what % of missing values are there for each var
        ccm.isna()      # ccm.isna() TURNS every obs/variable = 1 when its missing and 0 else
       .sum(axis=0)     # count the number of na for each variable (now data is 1 obs per column = # missing)
        /len(ccm)       # convert # missing to % missing 
        *100            # report as percentage
    ) 
    # you can stop here and report this...
    # but I wanted to format it a bit...
    .sort_values(ascending=False)[:20]
    .to_frame(name='% missing') # the next line only works on a frame, and because pandas sees only 1 variable at this pt
    .style.format("{:.1f}")     # in the code, it calls this a "series" type object, so convert it to dataframe type object
)
#
# Out:
# <style type="text/css">
# </style>
# <table id="T_ba5fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba5fe_level0_col0" class="col_heading level0 col0" >% missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba5fe_level0_row0" class="row_heading level0 row0" >capxv</th>
#       <td id="T_ba5fe_row0_col0" class="data row0 col0" >16.3</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row1" class="row_heading level0 row1" >oibdp</th>
#       <td id="T_ba5fe_row1_col0" class="data row1 col0" >11.4</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row2" class="row_heading level0 row2" >invt</th>
#       <td id="T_ba5fe_row2_col0" class="data row2 col0" >8.9</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row3" class="row_heading level0 row3" >capx</th>
#       <td id="T_ba5fe_row3_col0" class="data row3 col0" >8.7</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row4" class="row_heading level0 row4" >rect</th>
#       <td id="T_ba5fe_row4_col0" class="data row4 col0" >8.5</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row5" class="row_heading level0 row5" >acominc</th>
#       <td id="T_ba5fe_row5_col0" class="data row5 col0" >8.3</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row6" class="row_heading level0 row6" >ap</th>
#       <td id="T_ba5fe_row6_col0" class="data row6 col0" >8.3</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row7" class="row_heading level0 row7" >epsfx</th>
#       <td id="T_ba5fe_row7_col0" class="data row7 col0" >8.1</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row8" class="row_heading level0 row8" >ib</th>
#       <td id="T_ba5fe_row8_col0" class="data row8 col0" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row9" class="row_heading level0 row9" >ni</th>
#       <td id="T_ba5fe_row9_col0" class="data row9 col0" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row10" class="row_heading level0 row10" >cogs</th>
#       <td id="T_ba5fe_row10_col0" class="data row10 col0" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row11" class="row_heading level0 row11" >gp</th>
#       <td id="T_ba5fe_row11_col0" class="data row11 col0" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row12" class="row_heading level0 row12" >sale</th>
#       <td id="T_ba5fe_row12_col0" class="data row12 col0" >8.0</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row13" class="row_heading level0 row13" >at</th>
#       <td id="T_ba5fe_row13_col0" class="data row13 col0" >7.7</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row14" class="row_heading level0 row14" >gvkey</th>
#       <td id="T_ba5fe_row14_col0" class="data row14 col0" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_ba5fe_level0_row15" class="row_heading level0 row15" >fyear</th>
#       <td id="T_ba5fe_row15_col0" class="data row15 col0" >0.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Understand Accounting Dataset

# %%
# what each var is
# ap - accounts payable (shows a company's financial ability to pay up/cover their finances)
# rect - receivbales/total (money they are waiting to receive)
# invt - inventory

# which var we want to use for net income
# ni will represent net income

# which var should we drop?
# oibdp, ib, acominc

# %%
# filter to just 2019 and 2022
# filter to have two observations for each gvkey
# drop unneeded variables

acct_df = merged_acct_raw_keys.query('fyear == 2019 or fyear == 2022')  ## changed this from acct_raw
value_counts = acct_df['gvkey'].value_counts()
acct_df2 = acct_df[acct_df['gvkey'].isin(value_counts.index[value_counts==2])].reset_index(drop=True)
#acct_df2.columns
acct_df3 = acct_df2[['gvkey', 'fyear', 'ap', 'at', 'capx', 'cogs', 'epsfx', 'gp', 'invt', 'ni', 'rect', 'sale']]
acct_df3

print(acct_df['gvkey'].nunique())
print(acct_df2['gvkey'].nunique())
print(acct_df3['gvkey'].nunique())
# Out:
# 354
# 331
# 331

# %%
# filter to just 2019 and 2021
# filter to have two observations for each gvkey
# drop unneeded variables

acct_df_21 = merged_acct_raw_keys.query('fyear == 2019 or fyear == 2021')
value_counts_21 = acct_df_21['gvkey'].value_counts()
acct_df2_21 = acct_df_21[acct_df_21['gvkey'].isin(value_counts_21.index[value_counts_21==2])].reset_index(drop=True)
#acct_df2.columns
acct_df3_21 = acct_df2_21[['gvkey', 'fyear', 'ap', 'at', 'capx', 'cogs', 'epsfx', 'gp', 'invt', 'ni', 'rect', 'sale']]
acct_df3_21

print(acct_df_21['gvkey'].nunique())
print(acct_df2_21['gvkey'].nunique())
print(acct_df3_21['gvkey'].nunique())
# Out:
# 354
# 351
# 351

# %%
# create new variables

acct_df4 = acct_df3
ap_value = 0
at_value = 0
capx_value = 0
cogs_value = 0
epsfx_value = 0
gp_value = 0
invt_value = 0
ni_value = 0
rect_value = 0
sale_value = 0

for index, row in acct_df4.iterrows():
    # row can be used like row['var_name']
    if index%2 ==0:
        #recording the value of the 2019
        ap_value = row['ap']
        at_value = row['at']
        capx_value = row['capx']
        cogs_value = row['cogs']
        epsfx_value = row['epsfx']
        gp_value = row['gp']
        invt_value = row['invt']
        ni_value = row['ni']
        rect_value = row['rect']
        sale_value = row['sale']
    if index%2 ==1:
        # calculating the % change
        calc_ap_value = (row['ap'] - ap_value) / ap_value * 100
        calc_at_value = (row['at'] - at_value) / at_value * 100
        calc_capx_value = (row['capx'] - capx_value) / capx_value * 100
        calc_cogs_value = (row['cogs'] - cogs_value) / cogs_value * 100
        calc_epsfx_value = (row['epsfx'] - epsfx_value) / epsfx_value * 100
        calc_gp_value = (row['gp'] - gp_value) / gp_value * 100
        calc_invt_value = (row['invt'] - invt_value) / invt_value * 100
        calc_ni_value = (row['ni'] - ni_value) / ni_value * 100
        calc_rect_value = (row['rect'] - rect_value) / rect_value * 100
        calc_sale_value = (row['sale'] - sale_value) / sale_value * 100
        
        # adding it to the df
        acct_df4.loc[index,'calc_ap_value'] = calc_ap_value
        acct_df4.loc[index,'calc_at_value'] = calc_at_value
        acct_df4.loc[index,'calc_capx_value'] = calc_capx_value
        acct_df4.loc[index,'calc_cogs_value'] = calc_cogs_value
        acct_df4.loc[index,'calc_epsfx_value'] = calc_epsfx_value
        acct_df4.loc[index,'calc_gp_value'] = calc_gp_value
        acct_df4.loc[index,'calc_invt_value'] = calc_invt_value
        acct_df4.loc[index,'calc_ni_value'] = calc_ni_value
        acct_df4.loc[index,'calc_rect_value'] = calc_rect_value
        acct_df4.loc[index,'calc_sale_value'] = calc_sale_value
        
acct = acct_df4
acct.to_csv("outputs/acct.csv", index= False)

acct_df4.describe().T
# Out:
# /var/folders/gs/31y981014b72656vt76cm2kr0000gn/T/ipykernel_8857/682510891.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acct_df4.loc[index,'calc_ap_value'] = calc_ap_value
# /var/folders/gs/31y981014b72656vt76cm2kr0000gn/T/ipykernel_8857/682510891.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acct_df4.loc[index,'calc_at_value'] = calc_at_value
# /var/folders/gs/31y981014b72656vt76cm2kr0000gn/T/ipykernel_8857/682510891.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acct_df4.loc[index,'calc_capx_value'] = calc_capx_value
# /var/folders/gs/31y981014b72656vt76cm2kr0000gn/T/ipykernel_8857/682510891.py:37: RuntimeWarning: invalid value encountered in double_scalars
#   calc_invt_value = (row['invt'] - invt_value) / invt_value * 100
# /var/folders/gs/31y981014b72656vt76cm2kr0000gn/T/ipykernel_8857/682510891.py:33: RuntimeWarning: invalid value encountered in double_scalars
#   calc_capx_value = (row['capx'] - capx_value) / capx_value * 100
# /var/folders/gs/31y981014b72656vt76cm2kr0000gn/T/ipykernel_8857/682510891.py:31: RuntimeWarning: divide by zero encountered in double_scalars
#   calc_ap_value = (row['ap'] - ap_value) / ap_value * 100
# /var/folders/gs/31y981014b72656vt76cm2kr0000gn/T/ipykernel_8857/682510891.py:39: RuntimeWarning: invalid value encountered in double_scalars
#   calc_rect_value = (row['rect'] - rect_value) / rect_value * 100
# /var/folders/gs/31y981014b72656vt76cm2kr0000gn/T/ipykernel_8857/682510891.py:37: RuntimeWarning: divide by zero encountered in double_scalars
#   calc_invt_value = (row['invt'] - invt_value) / invt_value * 100
# /var/folders/gs/31y981014b72656vt76cm2kr0000gn/T/ipykernel_8857/682510891.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   calc_cogs_value = (row['cogs'] - cogs_value) / cogs_value * 100
#                   count          mean            std           min  \
# gvkey             662.0  4.639679e+04   61302.483972   1075.000000
# fyear             662.0  2.020500e+03       1.501134   2019.000000
# ap                658.0  1.442408e+04  126810.311036      0.000000
# at                662.0  6.289927e+04  227005.965270    956.375000
# capx              662.0  1.604341e+03    3445.105367      0.000000
# cogs              662.0  1.730350e+04   40116.887409      0.000000
# epsfx             662.0  6.894260e+00      22.911088   -121.790000
# gp                662.0  9.906425e+03   19069.459326 -17188.000000
# invt              651.0  3.031198e+03   14429.966550      0.000000
# ni                662.0  2.748175e+03    7273.057118 -22819.000000
# rect              658.0  1.113364e+04   73475.093310      0.000000
# sale              662.0  2.720992e+04   54038.865167     60.209000
# calc_ap_value     328.0           inf            NaN   -100.000000
# calc_at_value     331.0  3.917502e+01     109.723559    -49.803770
# calc_capx_value   320.0  2.878986e+01      85.254980    -76.414932
# calc_cogs_value   330.0  3.718385e+01      60.219883    -63.684258
# calc_epsfx_value  331.0 -7.751638e+00     566.688495  -5400.000000
# calc_gp_value     331.0  2.415709e+01     168.371159  -2857.922592
# calc_invt_value   259.0           inf            NaN    -88.235294
# calc_ni_value     331.0  2.907479e+01     809.623498  -5710.738255
# calc_rect_value   328.0  7.223892e+01     560.934933    -69.714286
# calc_sale_value   331.0  1.297195e+02    1751.647034    -60.097238
#
#                           25%           50%           75%           max
# gvkey             6156.000000  13125.000000  63149.000000  3.160560e+05
# fyear             2019.000000   2020.500000   2022.000000  2.022000e+03
# ap                 335.852250   1014.223000   2706.250000  2.340179e+06
# at                9848.635000  20889.550000  49435.100000  3.665743e+06
# capx               150.137250    489.200000   1588.199000  3.148500e+04
# cogs              2285.845750   6298.000000  12764.000000  4.527760e+05
# epsfx                2.092500      4.495000      7.797500  4.918200e+02
# gp                2231.425000   4007.600000   9180.750000  1.794820e+05
# invt               118.850000    778.300000   2254.132000  2.588080e+05
# ni                 516.990000   1036.900000   2706.750000  9.980300e+04
# rect               738.500000   1596.500000   4340.954500  1.111951e+06
# sale              5377.300000  11091.000000  22304.818500  6.084810e+05
# calc_ap_value       14.381166     36.014630     61.719720           inf
# calc_at_value        5.251981     18.863301     45.210870  1.526881e+03
# calc_capx_value     -9.428735     15.781622     48.265294  1.167668e+03
# calc_cogs_value     11.972971     27.523388     45.150898  7.815323e+02
# calc_epsfx_value   -30.288491     17.690875     61.274325  5.600000e+03
# calc_gp_value        6.407170     19.989652     51.023763  3.675000e+02
# calc_invt_value     21.835606     40.188806     70.695426           inf
# calc_ni_value      -20.233774     20.097861     71.481672  1.227262e+04
# calc_rect_value      4.354525     26.392899     54.646088  1.011047e+04
# calc_sale_value     12.448786     24.741773     44.807988  3.189356e+04

# %%
## create new variables (simplified code with ChatGTP)

# acct_df5 = acct_df3
# prev_row = acct_df5.iloc[0]
# for index, row in acct_df5.iloc[1:].iterrows():
#     if index % 2 == 1:
#         calc_row = (row - prev_row) / prev_row * 100
#         calc_row.rename({k: f"calc_{k}" for k in calc_row.index}, inplace=True)
#         acct_df5.loc[index, calc_row.index] = calc_row
#     else:
#         prev_row = row

# acct_2022 = acct_df5
# acct_2022.describe().T
# acct_2022['gvkey'].nunique()

# %%
## create new variables (simplified code with ChatGTP) - 2021

# acct_df5 = acct_df3_21
# prev_row = acct_df5.iloc[0]
# for index, row in acct_df5.iloc[1:].iterrows():
#     if index % 2 == 1:
#         calc_row = (row - prev_row) / prev_row * 100
#         calc_row.rename({k: f"calc_{k}" for k in calc_row.index}, inplace=True)
#         acct_df5.loc[index, calc_row.index] = calc_row
#     else:
#         prev_row = row

# acct_2021 = acct_df5
# acct_2021.describe().T
# acct_2021['gvkey'].nunique()

# %%
## testing
acct_df_21_22 = acct_raw.query('fyear == 2019 or fyear == 2021 or fyear == 2022')
value_counts_21_22 = acct_df_21_22['gvkey'].value_counts()
acct_df2_21_22 = acct_df_21_22[acct_df_21_22['gvkey'].isin(value_counts_21_22.index[value_counts_21_22==3])].reset_index(drop=True)
acct_df3_21_22 = acct_df2_21_22[['gvkey', 'fyear', 'ap', 'at', 'capx', 'cogs', 'epsfx', 'gp', 'invt', 'ni', 'rect', 'sale']]

acct_df6 = acct_df3_21_22
#prev_prev_row = acct_df5.iloc[0]
prev_row = acct_df6.iloc[0]
for index, row in acct_df6.iloc[1:].iterrows():
    if row.values[1] == 2019.0:
        prev_row = row
    elif row.values[1] == 2021.0:
        calc_row = (row - prev_row) / prev_row * 100
        calc_row.rename({k: f"calc_{k}" for k in calc_row.index}, inplace=True)
        acct_df6.loc[index, calc_row.index] = calc_row
    elif row.values[1] == 2022.0:
        calc_row = (row - prev_row) / prev_row * 100
        calc_row.rename({k: f"calc_{k}" for k in calc_row.index}, inplace=True)
        acct_df6.loc[index, calc_row.index] = calc_row

# print(acct_df3_21_22['gvkey'].nunique())
# len(acct_df3_21_22.query('fyear == 2019'))

# %% [markdown]
# # The Final Dataset

# %%
filtered_out_df.columns
# Out:
# Index(['gvkey', 'cid', 'cnms', 'ctype', 'gareac', 'gareat', 'salecs', 'sid',
#        'stype', 'srcdate', 'conm', 'tic', 'cusip', 'CIK', 'sic', 'Symbol',
#        'Security', 'GICS Sector', 'GICS Sub-Industry', 'Headquarters Location',
#        'Date added', 'Founded', 'date'],
#       dtype='object')

# %%
# merge acct with filtered_out_df
filtered_out_df['fyear'] = pd.to_datetime(filtered_out_df['srcdate']).dt.year
comp_final = filtered_out_df[['gvkey','cnms', 'ctype', 'salecs','srcdate', 'conm', 'tic', 'cusip', 'CIK', 'sic', 'Symbol','GICS Sector','fyear']]

# %%
# Select the desired columns from comp_final
cleaned_comp = comp_final[['gvkey', 'fyear', 'conm', 'Symbol', 'CIK']]

# Drop duplicates from df2_subset
cleaned_comp = cleaned_comp.drop_duplicates()

cleaned_comp.to_csv('cleaned_comp.csv')

# Merge df1 with df2_subset on the 'gvkey' and 'fyear' columns
# merged_df = pd.merge(df1, df2_subset, on=['gvkey', 'fyear'], how='left')
print(filtered_out_df['gvkey'].nunique())
print(comp_final['gvkey'].nunique())
print(cleaned_comp['gvkey'].nunique())
print("acct_raw length",len(acct_raw))
# print(acct['gvkey'].nunique()) # w/ accounting calculations
# print(acct.shape)




# with acct (with the long way to calculate variables)
accounting = cleaned_comp.merge(acct, how='right',on=['gvkey','fyear'], indicator=True)
value_counts2 = accounting['gvkey'].value_counts()
accounting2 = accounting[accounting['gvkey'].isin(value_counts2.index[value_counts2==2])].reset_index(drop=True)
print(accounting['gvkey'].nunique())
print(accounting2['gvkey'].nunique())


# accounting = cleaned_comp.merge(acct_2021, how='left',on=['gvkey','fyear'], indicator=True)
# value_counts2 = accounting['gvkey'].value_counts()
# accounting2 = accounting[accounting['gvkey'].isin(value_counts2.index[value_counts2==2])].reset_index(drop=True)
# print(accounting['gvkey'].nunique())
# print(accounting2['gvkey'].nunique())

# accounting = cleaned_comp.merge(acct_2021, how='left',on=['gvkey','fyear'], indicator=True)
# value_counts2 = accounting['gvkey'].value_counts()
# accounting2 = accounting[accounting['gvkey'].isin(value_counts2.index[value_counts2==2])].reset_index(drop=True)
# print(accounting['gvkey'].nunique())
# print(accounting2['gvkey'].nunique())
# Out:
# 355
# 355
# 355
# acct_raw length 26905
# 331
# 329

# %%
# merging
final = comp_final.merge(acct, how='inner',on=['gvkey','fyear'])
final
# Out:
#        gvkey                                     cnms    ctype    salecs  \
# 0       1075  Retail non-residential electric service   MARKET  1509.514
# 1       1075      Retail residential electric service   MARKET  1761.122
# 2       1075                   Wholesale energy sales   MARKET   121.805
# 3       1075                            Other sources   MARKET    16.308
# 4       1075         Transmission services for others   MARKET    62.460
# ...      ...                                      ...      ...       ...
# 3184  189491                                Treatment   MARKET   397.000
# 3185  189491                                Transport   MARKET  1780.000
# 3186  316056                                 Non-U.S.   GEOREG   865.100
# 3187  316056                            United States   GEOREG  1988.900
# 3188  316056                             10 Customers  COMPANY   656.420
#
#          srcdate                        conm   tic      cusip        CIK  \
# 0     2019-12-31  PINNACLE WEST CAPITAL CORP   PNW  723484101   764622.0
# 1     2019-12-31  PINNACLE WEST CAPITAL CORP   PNW  723484101   764622.0
# 2     2019-12-31  PINNACLE WEST CAPITAL CORP   PNW  723484101   764622.0
# 3     2019-12-31  PINNACLE WEST CAPITAL CORP   PNW  723484101   764622.0
# 4     2019-12-31  PINNACLE WEST CAPITAL CORP   PNW  723484101   764622.0
# ...          ...                         ...   ...        ...        ...
# 3184  2019-12-31                   XYLEM INC   XYL  98419M100  1524472.0
# 3185  2019-12-31                   XYLEM INC   XYL  98419M100  1524472.0
# 3186  2019-12-31                ALLEGION PLC  ALLE  G0176J109  1579241.0
# 3187  2019-12-31                ALLEGION PLC  ALLE  G0176J109  1579241.0
# 3188  2019-12-31                ALLEGION PLC  ALLE  G0176J109  1579241.0
#
#        sic  ... calc_ap_value calc_at_value  calc_capx_value  calc_cogs_value  \
# 0     4911  ...           NaN           NaN              NaN              NaN
# 1     4911  ...           NaN           NaN              NaN              NaN
# 2     4911  ...           NaN           NaN              NaN              NaN
# 3     4911  ...           NaN           NaN              NaN              NaN
# 4     4911  ...           NaN           NaN              NaN              NaN
# ...    ...  ...           ...           ...              ...              ...
# 3184  3561  ...           NaN           NaN              NaN              NaN
# 3185  3561  ...           NaN           NaN              NaN              NaN
# 3186  3420  ...           NaN           NaN              NaN              NaN
# 3187  3420  ...           NaN           NaN              NaN              NaN
# 3188  3420  ...           NaN           NaN              NaN              NaN
#
#       calc_epsfx_value  calc_gp_value  calc_invt_value  calc_ni_value  \
# 0                  NaN            NaN              NaN            NaN
# 1                  NaN            NaN              NaN            NaN
# 2                  NaN            NaN              NaN            NaN
# 3                  NaN            NaN              NaN            NaN
# 4                  NaN            NaN              NaN            NaN
# ...                ...            ...              ...            ...
# 3184               NaN            NaN              NaN            NaN
# 3185               NaN            NaN              NaN            NaN
# 3186               NaN            NaN              NaN            NaN
# 3187               NaN            NaN              NaN            NaN
# 3188               NaN            NaN              NaN            NaN
#
#       calc_rect_value  calc_sale_value
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
# ...               ...              ...
# 3184              NaN              NaN
# 3185              NaN              NaN
# 3186              NaN              NaN
# 3187              NaN              NaN
# 3188              NaN              NaN
#
# [3189 rows x 33 columns]

# %%
# mergingV2 - TEST!!!
final2 = acct.merge(comp_final, how='right',on=['gvkey','fyear'])
final2

final2['gvkey'].nunique()
# Out:
# 355

# %%
final.to_csv("outputs/final.csv", index = False)

# %%
# # to see # unique firms
# fin = final.groupby("CIK")['cnms'].apply(lambda x: list(np.unique(x)))
# len(fin)

# %%
# # Filter out rows with fyear equal to 2019
# final_2022 = final[final['fyear'] == 2022]

# # Save the filtered dataset as a new CSV file
# final_2022.to_csv("outputs/final_2022.csv", index=False)
